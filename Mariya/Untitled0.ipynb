# %%
import matplotlib.pyplot as plt

with open("3_data.txt") as f:
    data = f.read()

data = data.split('\n')

x = [row.split(' ')[0] for row in data]
y = [row.split(' ')[1] for row in data]
plt.plot(x, y)

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d7a8d5827445> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 with open("3_data.txt") as f:
#       4     data = f.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '3_data.txt'
